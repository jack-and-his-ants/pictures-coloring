# %%
import torch
import numpy as np
import joblib
import matplotlib.pyplot as plt
from src.utils.device import get_device
from src.models.colorization_network import ColorizationNetwork

from PIL import Image
from skimage import color

# %%
device = get_device()
print(device)
# Out:
# mps

# %%
model = ColorizationNetwork(n_classes=32)
checkpoint = torch.load("checkpoints/best_model.pth",map_location=device)

# %%
model.load_state_dict(
    checkpoint["model_state_dict"]
)
# Out:
# <All keys matched successfully>

# %%
model.to(device)
# Out:
# ColorizationNetwork(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
kmeans = joblib.load('../test_kmeans.pkl')

# %%
def show_images(original,colorized):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(original)
    plt.title("Original")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(
        color.rgb2gray(original),
        cmap="gray"
    )
    plt.title("Input L")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(colorized)
    plt.title("Colorized")
    plt.axis("off")

    plt.show()

# %%
from src.inference.colorize import colorize_image

# %%
original,colorized,classes=colorize_image("../data/test/Image_1.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_3.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_5.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_6.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_7.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_13.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_15.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_122.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_123.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_125.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_126.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_127.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_128.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_129.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_132.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_133.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_134.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_135.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)

# %%
original,colorized,classes=colorize_image("../data/test/Image_136.jpg",model,kmeans,(128,128),device)
show_images(original,colorized)
